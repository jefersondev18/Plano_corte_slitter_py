# %%
import pandas as pd
import os
import platform

# %%
SO = platform.system()

if SO == 'Windows':
    BASE_INPUT = r'C:\Users\marce\OneDrive\Documentos\GitHub\plano_corte\input'
    BASE_OUTPUT = r'C:\Users\marce\OneDrive\Documentos\GitHub\plano_corte\output'
elif SO == 'Linux':
    BASE_INPUT = r'/home/stark/Documentos/Dev/Plano_corte_py/files/input'
    BASE_OUTPUT = r'/home/stark/Documentos/Dev/Plano_corte_py/files/output'
    

else:
    raise Exception('Sistema Operacional não suportado')

# %%
db_plano_corte = pd.read_excel(os.path.join(BASE_INPUT, 'db_plano_corte.xlsx'))

# %% [markdown]
# # Variaveis para os Calculos
#
# **Coluna "Soma dos cortes (mm)"** = somatório(coluna "Desenvolvimento" * coluna "Número de corte")
#
# **plano_corte** = soma dos valores encontrados na coluna "Soma dos cortes (mm)"
#
# **perda_milimetros** = Largura da bobina - plano_corte
#
#
# *máximo 1,7%*
# **perda_percentual** = perda_milimetros / Largura da bobina
#
# # Regra de negócio.
#
# '''
# Usuário escolhe os parametros:
# espessura, tipo de material e uma matriz
#
# o script precisa retornar todas as combinações de matrizes da mesma espessura e tipo, que consiga manter o percentual de perda entre (0,67% e 1,7%)
#
#
# '''

# %%
db_plano_corte.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1269 entries, 0 to 1268
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Código                1269 non-null   object
#  1   Espessura             1263 non-null   float64
#  2   Matriz                1105 non-null   str
#  3   Tipo de material      1119 non-null   str
#  4   Produto               1263 non-null   str
#  5   Desenvolvimento       1269 non-null   float64
#  6   Número de corte       1269 non-null   int64
#  7   Soma dos cortes (mm)  1269 non-null   int64
# dtypes: float64(2), int64(2), object(1), str(3)
# memory usage: 79.4+ KB

# %%
db_plano_corte['Desenvolvimento'] = pd.to_numeric(db_plano_corte['Desenvolvimento'], errors='coerce', downcast='float')

# %%
db_plano_corte.head()
# Out:
#    Código  Espessura    Matriz Tipo de material                      Produto  \
# 0  200292       3.00  50,80-2"        COMERCIAL        FT FQ 2" 3,00X154,0MM
# 1  200046       2.00  50,80-2"        COMERCIAL        FT FQ 2" 2,00X157,0MM
# 2  200035       1.20  25,40-1"        COMERCIAL         FT FF 1" 1,20X79,0MM
# 3  200117       2.00  75X40X15        COMERCIAL  FT FQ 75X40X15 2,00X167,0MM
# 4  200223       2.25  76,20-3"        COMERCIAL        FT FQ 3" 2,25X236,0MM
#
#    Desenvolvimento  Número de corte  Soma dos cortes (mm)
# 0            154.0                0                     0
# 1            157.0                0                     0
# 2             79.0                0                     0
# 3            169.0                0                     0
# 4            236.0                0                     0
